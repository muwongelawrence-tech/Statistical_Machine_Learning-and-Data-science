# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading data from the downloaded CSV:
# 1. We can set the index at load time
movies_df = pd.read_csv("IMDB-Movie-Data.csv",index_col='Title')

# Viewing the Data#
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
# To ouput the top ten rows
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
# Viewing the last  5 rows of the Data#
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
# Viewing the last  10 rows of the Data#
movies_df.tail(10)
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Take Me Home Tonight             993      Comedy,Drama,Romance
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
# Secret in Their Eyes             996       Crime,Drama,Mystery
# Hostel: Part II                  997                    Horror
# Step Up 2: The Streets           998       Drama,Music,Romance
# Search Party                     999          Adventure,Comedy
# Nine Lives                      1000     Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
# Taare Zameen Par                An eight-year-old boy is thought to be a lazy ...
# ...

# %%
# Viewing some information about the data set.
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
# Viewing the shape of the data set.
movies_df.shape
# Out:
# (1000, 11)

# %%
# lets describe the dataset and do some quick analysis of the data.
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
# To obtain a Series as output
col_as_series = movies_df['Genre']

# Print the object type and the first 5 rows of the series
print(type(col_as_series))
col_as_series.head()
# Out:
# <class 'pandas.core.series.Series'>
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
# Name: Genre, dtype: object

# %%
# To obtain a dataFrame as output
col_as_df = movies_df[['Genre']]

# Print the object type and the first 5 rows of the DF
print(type(col_as_df))
col_as_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                             Genre
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy

# %%
#Since it's just a list, adding another column name is easy:
extracted_cols = movies_df[['Genre', 'Rating', 'Revenue (Millions)']]

extracted_cols.head()
# Out:
#                                             Genre  Rating  Revenue (Millions)
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi     8.1              333.13
# Prometheus               Adventure,Mystery,Sci-Fi     7.0              126.46
# Split                             Horror,Thriller     7.3              138.12
# Sing                      Animation,Comedy,Family     7.2              270.32
# Suicide Squad            Action,Adventure,Fantasy     6.2              325.02

# %%
# Now let’s look at how to perform slicing by rows.using loc , iloc and ix.
# With loc we give the explicit index. In our case the title, "Guardians of the Galaxy":
gog = movies_df.loc["Guardians of the Galaxy"]
gog
# Out:
# Rank                                                                  1
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: Guardians of the Galaxy, dtype: object

# %%
# With iloc we give it the numerical index of "Guardians of the Galaxy":
gog = movies_df.iloc[0]
gog
# Out:
# Rank                                                                  1
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: Guardians of the Galaxy, dtype: object

# %%
# We can also get slices with multiple rows in the same manner:
multiple_rows = movies_df.loc['Guardians of the Galaxy':'Sing']


multiple_rows
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
#
# ...

# %%
# Or we can get the same result using iloc
multiple_rows = movies_df.iloc[0:4]

    
multiple_rows
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
#
# ...

# %%
# Select all rows uptil 'Sing' and all columns uptil 'Director'
movies_df.loc[:'Sing', :'Director']
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
#
#                                      Director
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet

# %%
# same operation using iloc
movies_df.iloc[:4, :3]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
#
#                                                                Description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...

# %%
#  Conditional Data Selection and Filtering#
# We can easily filter rows using the values of a specific row. 
# For example, for geting all our 2016 movies:
movies_df[movies_df['Year'] == 2016]
# Out:
#                                 Rank                     Genre  \
# Title
# Split                              3           Horror,Thriller
# Sing                               4   Animation,Comedy,Family
# Suicide Squad                      5  Action,Adventure,Fantasy
# The Great Wall                     6  Action,Adventure,Fantasy
# La La Land                         7        Comedy,Drama,Music
# ...                              ...                       ...
# My Big Fat Greek Wedding 2       976     Comedy,Family,Romance
# Amateur Night                    978                    Comedy
# It's Only the End of the World   979                     Drama
# Miracles from Heaven             981    Biography,Drama,Family
# Nine Lives                      1000     Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Split                           Three girls are kidnapped by a man with a diag...
# ...

# %%
# All our movies with a rating higher than 8.0 
movies_df[movies_df['Rating'] > 8.0 ]
# Out:
#                                               Rank  \
# Title
# Guardians of the Galaxy                          1
# La La Land                                       7
# Hacksaw Ridge                                   17
# Lion                                            19
# Bahubali: The Beginning                         27
# Interstellar                                    37
# Star Wars: Episode VII - The Force Awakens      51
# The Dark Knight                                 55
# The Prestige                                    65
# Mad Max: Fury Road                              68
# Zootopia                                        75
# The Avengers                                    77
# Inglourious Basterds                            78
# Inception                                       81
# The Wolf of Wall Street                         83
# Gone Girl                                       84
# Prisoners                                       91
# ...

# %%
# Now let’s look at some more complex filters. We can make our conditions richer
# with logical operators like “|” and “&”.
# Say we want to retrieve the latest movies (movies released between 2010 and 2016) that had a very
# poor rating (score less than 6.0) but were among the highest earners at the 
# box office (revenue above the 75th percentile).

movies_df[
    ((movies_df['Year'] >= 2010) & (movies_df['Year'] <= 2016))
    & (movies_df['Rating'] < 6.0)
    & (movies_df['Revenue (Millions)'] > movies_df['Revenue (Millions)'].quantile(0.75))
]
# Out:
#                                            Rank                     Genre  \
# Title
# Fifty Shades of Grey                         64    Drama,Romance,Thriller
# Ghostbusters                                 80     Action,Comedy,Fantasy
# Transformers: Age of Extinction             127   Action,Adventure,Sci-Fi
# The Twilight Saga: Breaking Dawn - Part 2   367   Adventure,Drama,Fantasy
# Grown Ups 2                                 395                    Comedy
# Clash of the Titans                         576  Action,Adventure,Fantasy
# Kickboxer: Vengeance                        581                    Action
# Teenage Mutant Ninja Turtles                658   Action,Adventure,Comedy
# Green Lantern                               674   Action,Adventure,Sci-Fi
# G.I. Joe: Retaliation                       879   Action,Adventure,Sci-Fi
# The Twilight Saga: Breaking Dawn - Part 1   926   Adventure,Drama,Fantasy
# The Twilight Saga: Eclipse                  942   Adventure,Drama,Fantasy
# ...

# %%
# Let’s group our dataset by director and see how much revenue each director has
movies_df.groupby('Director').sum()
# Out:
#                      Rank   Year  Runtime (Minutes)  Rating    Votes  \
# Director
# Aamir Khan            992   2007                165     8.5   102697
# Abdellatif Kechiche   312   2013                180     7.8   103150
# Adam Leon             784   2016                 82     6.5     1031
# Adam McKay           1910   8039                443    28.0   806827
# Adam Shankman        1460   4019                240    12.6   167467
# ...                   ...    ...                ...     ...      ...
# Xavier Dolan         1588   4030                236    15.1    44218
# Yimou Zhang             6   2016                103     6.1    56036
# Yorgos Lanthimos      479   4024                213    14.4   172259
# Zack Snyder           904  10055                683    35.2  2301544
# Zackary Adler         605   2015                110     5.1     1630
#
#                      Revenue (Millions)  Metascore
# Director
# Aamir Khan                         1.20       42.0
# ...

# %%
# Let’s group our dataset by director and see the average rating of each director
# In addition to sum() and mean() Pandas provides multiple other aggregation functions like min()and max().
movies_df.groupby('Director')[['Rating']].mean()
# Out:
#                      Rating
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
# ...                     ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
#
# [644 rows x 1 columns]

# %%
# Sorting#
#Let’s group our dataset by director and see who earned the most
movies_df.groupby('Director')[['Revenue (Millions)']].sum().sort_values(['Revenue (Millions)'], ascending=False)
# Out:
#                    Revenue (Millions)
# Director
# J.J. Abrams                   1683.45
# David Yates                   1630.51
# Christopher Nolan             1515.09
# Michael Bay                   1421.32
# Francis Lawrence              1299.81
# ...                               ...
# Jalil Lespert                    0.00
# Jamal Hill                       0.00
# James Franco                     0.00
# James Lapine                     0.00
# Greg Kwedar                      0.00
#
# [644 rows x 1 columns]

# %%
# Now, say we want to see which movies had both the highest revenue and the highest rating:
# Let's sort our movies by revenue and ratings and then get the top 10 results
data_sorted = movies_df.sort_values(['Revenue (Millions)','Rating'], ascending=False)
data_sorted[['Revenue (Millions)','Rating']].head(10)
# Out:
#                                             Revenue (Millions)  Rating
# Title
# Star Wars: Episode VII - The Force Awakens              936.63     8.1
# Avatar                                                  760.51     7.8
# Jurassic World                                          652.18     7.0
# The Avengers                                            623.28     8.1
# The Dark Knight                                         533.32     9.0
# Rogue One                                               532.17     7.9
# Finding Dory                                            486.29     7.4
# Avengers: Age of Ultron                                 458.99     7.4
# The Dark Knight Rises                                   448.13     8.5
# The Hunger Games: Catching Fire                         424.65     7.6

# %%
# Detecting Null Values#
# isnull() and notnull() are two useful methods for detecting null data for Pandas data structures.
# They return a Boolean mask over the data.
movies_df.isnull()
# Out:
#                           Rank  Genre  Description  Director  Actors   Year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
# We can also count the number of null values in each column using an aggregate function for summing:
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# Dropping Null Values#
# dropna() allows us to very easily drop rows or columns. 
# By default, this method will drop all rows in which any null value is present and return a new 
# DataFrame without altering the original one. If we want to modify our original DataFrame inplace instead, 
# we can specify inplace=True.

# Alternatively, we can drop all columns containing any null values by specifying axis=1.

# What does dropping data mean for our IMDB dataset?

# Dropping rows would remove 128 rows where revenue is null and 64 rows where metascore is null. 
# This is quite some data loss since there’s perfectly good data in the other columns of those dropped rows!
# Dropping columns would remove the revenue and metascore columns — not a smart move either!
# To avoid losing all this good data, we can also choose to drop rows or columns based on a threshold parameter,
# drop only if the majority of data is missing. This can be specified using the how or thresh parameters, 
# which allow fine control of the number of nulls to allow in through the DataFrame:

# # Drop columns where all the values are missing
# df.dropna(axis='columns', how='all')

# # Thresh to specify a minimum number of non-null values 
# # for the row/column to be kept
# df.dropna(axis='rows', thresh=10)

# %%
# Imputation (Filling Null Values)#
# As we have just seen, dropping rows or columns with missing data can result in losing a significant amount of 
# interesting data. So often, rather than dropping data, we replace missing values with a valid value.
# This new value can be a single number, like zero, or it can be some sort of imputation or interpolation from the 
# good values, like the mean or the median value of that column. For doing this, Pandas provides us with the very
# handy fillna() method for doing this

# Getting the mean value for the column:
revenue = movies_df['Revenue (Millions)']
revenue_mean = revenue.mean()
revenue_mean
# Out:
# 82.95637614678897

# %%
# Let's fill the nulls with the mean value:
revenue.fillna(revenue_mean, inplace=True)

# Let's get the updated status of our DataFrame:
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
#  Handling Duplicates#
# Pandas allows us to very easily remove duplicates by using the drop_duplicates() method. This method returns a copy of the DataFrame with duplicates removed 
# unless we choose to specify inplace=True,
movies_df.drop_duplicates()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
# Creating New Columns From Existing Columns#
# Often while analyzing data, we find ourselves needing to create new columns from existing ones. 
# Pandas makes this a breeze!
# Say we want to introduce a new column in our DataFrame that has revenue per minute for each movie. We can divide 
# the revenue by the runtime and create this new column very easily.

# We can use 'Revenue (Millions)' and 'Runtime (Minutes)' to calculate Revenue per Min for each movie:
movies_df['Revenue per Min'] = movies_df['Revenue (Millions)']/movies_df['Runtime (Minutes)']

movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
# Let's calculate the mean revenue per director but by using a pivot table instead of groupby as seen previously
movies_df.pivot_table('Revenue (Millions)', index='Director',
aggfunc='sum', columns='Year').head()
# Out:
# Year                   2006    2007    2008  2009    2010  2011   2012  2013  \
# Director
# Aamir Khan              NaN    1.20     NaN   NaN     NaN   NaN    NaN   NaN
# Abdellatif Kechiche     NaN     NaN     NaN   NaN     NaN   NaN    NaN   2.2
# Adam Leon               NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Adam McKay           148.21     NaN  100.47   NaN  119.22   NaN    NaN   NaN
# Adam Shankman           NaN  118.82     NaN   NaN     NaN   NaN  38.51   NaN
#
# Year                 2014   2015       2016
# Director
# Aamir Khan            NaN    NaN        NaN
# Abdellatif Kechiche   NaN    NaN        NaN
# Adam Leon             NaN    NaN  82.956376
# Adam McKay            NaN  70.24        NaN
# Adam Shankman         NaN    NaN        NaN

# %%
# Applying Functions#
# Applying functions to a dataset, apply(), is very handy for playing with data and creating new variables.
# For example, we could use a function to classify movies into four buckets (“great”, “good”, “average”, “bad”)
# based on their numerical ratings. We can do this in two steps:

# First, define a function that when given a rating determines the right bucket for that movie.
# Then apply that function to the DataFrame.

# 1. Let's define the function to put movies into buckets based on their rating
def rating_bucket(x):
    if x >= 8.0:
        return "great"
    elif x >= 7.0:
        return "good"
    elif x >= 6.0:
        return "average"
    else:
        return "bad"

# 2. Let's apply the function    
movies_df["Rating_Category"] = movies_df["Rating"].apply(rating_bucket)

# 3. Let's see some results
movies_df.head(10)[['Rating','Rating_Category']]
# Out:
#                          Rating Rating_Category
# Title
# Guardians of the Galaxy     8.1           great
# Prometheus                  7.0            good
# Split                       7.3            good
# Sing                        7.2            good
# Suicide Squad               6.2         average
# The Great Wall              6.1         average
# La La Land                  8.3           great
# Mindhorn                    6.4         average
# The Lost City of Z          7.1            good
# Passengers                  7.0            good

# %%
# Examples of available styles
# plt.style.use('classic')
# plt.style.use('ggplot')
# plt.style.use('seaborn-whitegrid')
# plt.style.use(['dark_background', 'presentation'])
# plt.style directive can be used to choose different prettyfying styles for our figures.

# If you are using Matplotlib from within a script, the function plt.show() is the way to go. 
# It triggers an event that looks for all currently active figure objects and opens one or more interactive
# windows to display them.

# Visualization Techniques#
# To create a scatter plot in Matplotlib we can simply use the scatter method.
# 2. Generating some random data

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

# 3. Create a scatterplot using the a colormap.
plt.scatter(x, y, c=colors, s=sizes, alpha=0.2,cmap ='viridis')
plt.colorbar();  # To show the color scale

# plt.savefig("output/scatter.png")

# %%
# 2. Line Plots#
# 2. Getting the Data
year = [1970, 1980, 1990, 2000, 2010, 2020]
pop_A = [4.9, 5.3, 7.1, 10.7, 13.5, 15.6]
pop_B = [44.4, 55.6, 69.7, 87.1, 95.4, 100.5]

# 3. Visualising the Data
plt.plot(year, pop_A, color='g')
plt.plot(year, pop_B, color='r')
plt.xlabel('Countries')
plt.ylabel('Population in million')
plt.title('Populations over the years')
# Out:
# Text(0.5, 1.0, 'Populations over the years')

# %%
# 3. Histograms#
# We can plot histograms using the hist() function:
data = np.random.randn(1000)
plt.hist(x=data);

# %%
# customized histogram for the same data
# plt.hist(data, bins=30, normed=True, alpha=0.5,
#                 histtype='stepfilled', color='steelblue',
#                 edgecolor='none');

# %%
# Input data
labels = ('Python', 'C++', 'Java', 'Perl', 'C#')
num_users = [12,8,15,4,6]
index = np.arange(len(labels))


# Plotting
plt.bar(index, num_users, align='center', alpha=0.5)
plt.xticks(index, labels)
plt.xlabel('Language')
plt.ylabel('Num of Users')
plt.title('Programming language usage')
# Out:
# Text(0.5, 1.0, 'Programming language usage')

# %%
# Create data
data_group1 = np.random.normal(100, 10, 200)
data_group2 = np.random.normal(80, 30, 200)
data_group3 = np.random.normal(90, 20, 200)

# combine these different datasets into a list    
data_to_plot = [data_group1, data_group2, data_group3]

# Create the boxplot
# patch_artist must be True to control box fill (color-filled boxes)
plt.boxplot(data_to_plot, patch_artist = True)

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Some Group Scores')
# Out:
# Text(0.5, 1.0, 'Some Group Scores')

# %%
# We can easily use the distplot() method to plot distributions in python
# Create some data that follows a Normal Distribution
x = np.random.normal(size=100)

# Plot the distribution
sns.distplot(x);
# Out:
# /home/lawrencepro/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
