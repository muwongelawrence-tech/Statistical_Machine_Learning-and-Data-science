# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib
# import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

import sys
import matplotlib
matplotlib.use('Agg')

# %% [markdown]
# # Dataset

# %%
myfile = pd.read_csv('UceResultsBySchool2011-2016.csv',header=0, sep=",")
myfile
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
myfile.shape
# Out:
# (17639, 48)

# %%
myfile.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
myfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                17639 non-null  int64
#  1   DISTRICT            17639 non-null  object
#  2   SCHOOL              17638 non-null  object
#  3   TOTAL CANDIDATES    17368 non-null  float64
#  4   TOTAL DIV 1         12858 non-null  float64
#  5   % DIV 1             17639 non-null  float64
#  6   TOTAL DIV 2         16880 non-null  float64
#  7   % DIV 2             17639 non-null  float64
#  8   TOTAL DIV 3         17168 non-null  float64
#  9   % DIV 3             17639 non-null  float64
#  10  TOTAL DIV 4         16888 non-null  float64
#  11  % DIV 4             17639 non-null  float64
#  12  TOTAL DIV 7         6489 non-null   float64
#  13  % DIV 7             17639 non-null  float64
#  14  TOTAL DIV 9         13454 non-null  float64
# ...

# %% [markdown]
# myfile.describle()

# %%
myfile.describe()
# Out:
#                YEAR  TOTAL CANDIDATES   TOTAL DIV 1       % DIV 1  \
# count  17639.000000      17368.000000  12858.000000  17639.000000
# mean    2013.582119        100.111469     10.348266      6.226481
# std        1.710821         66.964610     26.214334     13.266156
# min     2011.000000          1.000000      0.000000      0.000000
# 25%     2012.000000         54.000000      1.000000      0.000000
# 50%     2014.000000         84.000000      3.000000      1.800000
# 75%     2015.000000        128.000000      8.000000      5.700000
# max     2016.000000        499.000000    430.000000    100.000000
#
#         TOTAL DIV 2       % DIV 2   TOTAL DIV 3       % DIV 3   TOTAL DIV 4  \
# count  16880.000000  17639.000000  17168.000000  17639.000000  16888.000000
# mean      16.058649     14.748733     22.545841     22.165344     45.981348
# std       19.324105     12.800108     17.804404     10.241613     35.558741
# ...

# %%
myfile.columns = myfile.columns.to_series().apply(lambda x: x.strip())

# %%
myfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               17639 non-null  int64
#  1   DISTRICT           17639 non-null  object
#  2   SCHOOL             17638 non-null  object
#  3   TOTAL CANDIDATES   17368 non-null  float64
#  4   TOTAL DIV 1        12858 non-null  float64
#  5   % DIV 1            17639 non-null  float64
#  6   TOTAL DIV 2        16880 non-null  float64
#  7   % DIV 2            17639 non-null  float64
#  8   TOTAL DIV 3        17168 non-null  float64
#  9   % DIV 3            17639 non-null  float64
#  10  TOTAL DIV 4        16888 non-null  float64
#  11  % DIV 4            17639 non-null  float64
#  12  TOTAL DIV 7        6489 non-null   float64
#  13  % DIV 7            17639 non-null  float64
#  14  TOTAL DIV 9        13454 non-null  float64
# ...

# %%
myfile.columns
# Out:
# Index(['YEAR', 'DISTRICT', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1',
#        'FEMALE % DIV1', 'FEMALE TOTAL DIV2', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1', 'MALE % DIV1', 'MALE TOTAL DIV2',
#        'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3', 'MALE TOTAL DIV4',
#        'MALE % DIV4', 'MALE TOTAL DIV7', 'MALE % DIV7', 'MALE TOTAL DIV9',
#        'MALE % DIV9', 'MALE TOTAL X', 'MALE % X'],
#       dtype='object')

# %%
myfile.columns = myfile.columns.str.replace(' ', '_')
myfile.columns
# Out:
# Index(['YEAR', 'DISTRICT', 'SCHOOL', 'TOTAL_CANDIDATES', 'TOTAL_DIV_1',
#        '%_DIV_1', 'TOTAL_DIV_2', '%_DIV_2', 'TOTAL_DIV_3', '%_DIV_3',
#        'TOTAL_DIV_4', '%_DIV_4', 'TOTAL_DIV_7', '%_DIV_7', 'TOTAL_DIV_9',
#        '%_DIV_9', 'TOTAL_X', '%_X', 'FEMALE_CANDIDATES', 'FEMALE_TOTAL_DIV1',
#        'FEMALE_%_DIV1', 'FEMALE_TOTAL_DIV2', 'FEMALE_%_DIV2',
#        'FEMALE_TOTAL_DIV3', 'FEMALE_%_DIV3', 'FEMALE_TOTAL_DIV4',
#        'FEMALE_%_DIV4', 'FEMALE_TOTAL_DIV7', 'FEMALE_%_DIV7',
#        'FEMALE_TOTAL_DIV9', 'FEMALE_%_DIV9', 'FEMALE_TOTAL_X', 'FEMALE_%_X',
#        'MALE_CANDIDATES', 'MALE_TOTAL_DIV1', 'MALE_%_DIV1', 'MALE_TOTAL_DIV2',
#        'MALE_%_DIV2', 'MALE_TOTAL_DIV3', 'MALE_%_DIV3', 'MALE_TOTAL_DIV4',
#        'MALE_%_DIV4', 'MALE_TOTAL_DIV7', 'MALE_%_DIV7', 'MALE_TOTAL_DIV9',
#        'MALE_%_DIV9', 'MALE_TOTAL_X', 'MALE_%_X'],
#       dtype='object')

# %% [markdown]
# Cleaning out duplicates

# %%
#checking for duplicates and removing them
for isduplicate in myfile.duplicated().array:
    if isduplicate:
        print("Duplicates identified and dropped")
        myfile.drop_duplicates(inplace=True)
        
        break
    else:
        pass
    
    
print("This shows no duplicates available now..")  
myfile[myfile.duplicated()==True]
# Out:
# This shows no duplicates available now..
# Empty DataFrame
# Columns: [YEAR, DISTRICT, SCHOOL, TOTAL_CANDIDATES, TOTAL_DIV_1, %_DIV_1, TOTAL_DIV_2, %_DIV_2, TOTAL_DIV_3, %_DIV_3, TOTAL_DIV_4, %_DIV_4, TOTAL_DIV_7, %_DIV_7, TOTAL_DIV_9, %_DIV_9, TOTAL_X, %_X, FEMALE_CANDIDATES, FEMALE_TOTAL_DIV1, FEMALE_%_DIV1, FEMALE_TOTAL_DIV2, FEMALE_%_DIV2, FEMALE_TOTAL_DIV3, FEMALE_%_DIV3, FEMALE_TOTAL_DIV4, FEMALE_%_DIV4, FEMALE_TOTAL_DIV7, FEMALE_%_DIV7, FEMALE_TOTAL_DIV9, FEMALE_%_DIV9, FEMALE_TOTAL_X, FEMALE_%_X, MALE_CANDIDATES, MALE_TOTAL_DIV1, MALE_%_DIV1, MALE_TOTAL_DIV2, MALE_%_DIV2, MALE_TOTAL_DIV3, MALE_%_DIV3, MALE_TOTAL_DIV4, MALE_%_DIV4, MALE_TOTAL_DIV7, MALE_%_DIV7, MALE_TOTAL_DIV9, MALE_%_DIV9, MALE_TOTAL_X, MALE_%_X]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# # Inspect for null or NaN values

# %%
myfile.isna().any()
# Out:
# YEAR                 False
# DISTRICT             False
# SCHOOL                True
# TOTAL_CANDIDATES      True
# TOTAL_DIV_1           True
# %_DIV_1              False
# TOTAL_DIV_2           True
# %_DIV_2              False
# TOTAL_DIV_3           True
# %_DIV_3              False
# TOTAL_DIV_4           True
# %_DIV_4              False
# TOTAL_DIV_7           True
# %_DIV_7              False
# TOTAL_DIV_9           True
# %_DIV_9              False
# TOTAL_X               True
# %_X                  False
# FEMALE_CANDIDATES    False
# FEMALE_TOTAL_DIV1     True
# FEMALE_%_DIV1         True
# FEMALE_TOTAL_DIV2     True
# FEMALE_%_DIV2         True
# FEMALE_TOTAL_DIV3     True
# FEMALE_%_DIV3         True
# FEMALE_TOTAL_DIV4     True
# FEMALE_%_DIV4         True
# FEMALE_TOTAL_DIV7     True
# FEMALE_%_DIV7         True
# FEMALE_TOTAL_DIV9     True
# FEMALE_%_DIV9         True
# FEMALE_TOTAL_X        True
# FEMALE_%_X            True
# MALE_CANDIDATES      False
# ...

# %%
s = pd.Series([1,2,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    NaN
# 5    6.0
# 6    8.0
# dtype: float64

# %%
dates = pd.date_range("20220101", periods = 12)
df = pd.DataFrame(np.random.randn(12,4), index = dates , columns= list("ABCD"))
# df.columns
# df.index
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.275417 -0.692951  0.585277 -0.384230
# 2022-01-02 -0.273821  1.076066 -0.036387 -1.144941
# 2022-01-03 -0.653467  0.507086  0.181674  1.128490
# 2022-01-04  0.669009 -0.382462 -0.619152  1.195901
# 2022-01-05  0.835066 -0.037343 -1.812208 -1.105252
# 2022-01-06 -2.446025  2.339461  1.457268  0.926837
# 2022-01-07 -2.382689  0.082782  0.243380  1.385125
# 2022-01-08 -0.706947  1.037913  0.289399 -0.253645
# 2022-01-09  0.693816  2.328663 -0.022108 -1.541947
# 2022-01-10 -0.997226  0.505883 -0.774145  0.537910
# 2022-01-11 -0.557995 -0.640236  1.743673  0.477023
# 2022-01-12  0.731030  0.076699 -1.597977  0.334600
