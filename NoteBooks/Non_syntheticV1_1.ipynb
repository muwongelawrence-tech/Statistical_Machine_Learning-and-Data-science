# %% [markdown]
# Non-synthetic approach to the analysis.
# No imputation of data and all rows with missing data were dropped and columns with missing data and unusefull data.
#
# 1. Agasi Herbert
# 2. Kiberu Davis
# 3. Fredrick Kakembo

# %% [markdown]
# ## Installation of the missing libraries

# %%
#!pip install pycaret

# %% [markdown]
# # Loading the neccessary modules

# %%
from pycaret.classification import *
from sklearn.impute import SimpleImputer
import pandas as pd
import missingno as msno
#s = setup(data = data, target = 'Price', session_id=123)

# %% [markdown]
# ## Loading the data

# %%
data = pd.read_csv("/content/20-03-2023_hash_clean.csv")

# %% [markdown]
# ## Preview of the data

# %%
data.head()
# Out:
#    Study_ID  status Date_of_entry Date_of_Birth   Age  Religious_affiliation  \
# 0      5001     5.0    19-03-2019    19-12-2000  18.0                    1.0
# 1      5002     5.0    29-05-2019    28-12-1993  25.0                    1.0
# 2      5003     5.0    16-05-2019    07-11-1985  33.0                    2.0
# 3      5004     5.0    21-03-2019    08-05-1991  27.0                    1.0
# 4      5005     5.0    09-04-2019    02-10-1999  19.0                    1.0
#
#    Education  Marital_status  Tribe_mother  Tribe_father  ...  \
# 0        3.0             3.0           4.0           3.0  ...
# 1        4.0             1.0           3.0           3.0  ...
# 2        3.0             1.0           3.0           3.0  ...
# 3        6.0             1.0           3.0           3.0  ...
# 4        3.0             1.0           NaN           3.0  ...
#
#    abortions_ectopic  weight_less  weight_more_than  d_hyp  Months  \
# 0                NaN          NaN               NaN    NaN     NaN
# 1                0.0          1.0               1.0    1.0    77.0
# 2                0.0          1.0               2.0    1.0    30.0
# 3                0.0          1.0               2.0    1.0    70.0
# 4                1.0          1.0               1.0    1.0    11.0
#
#    preg_duration  condom  partner  H_infertility  Gestational_age
# 0            1.0     1.0      3.0            1.0             28.0
# 1            NaN     1.0      2.0            1.0             26.0
# 2            NaN     1.0      2.0            1.0             26.0
# 3            NaN     1.0      2.0            1.0              NaN
# 4            NaN     1.0      1.0            1.0             38.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Dimensions of the data

# %%
data.shape
# Out:
# (1006, 31)

# %% [markdown]
# ## Missing data
#
# Using the the msno libraary we can get a graphical interpretation of the the missing data.

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# ## Deriving the label
#
# - Changing all values greater than 0 to 1.
# - This is to get ensure the label is binary.

# %%
mapv ={
            0.0 : 0,
            1.0 : 1,
            2.0 : 1,
            3.0 : 1,
            4.0 : 1,
            5.0 : 1,
            6.0 : 1
            }
data["abortions_ectopic"].replace(mapv,inplace=True)

# %% [markdown]
# ## Filling the missing abortions_ecotpic with 9090 remove na

# %%
data["abortions_ectopic"].fillna(9090,inplace=True)
data = data[data["abortions_ectopic"]!=9090]

# %% [markdown]
# ### Finding the numbers within the data.

# %%
print(data.shape)
data.isna().sum()
# Out:
# (647, 31)
# Study_ID                   0
# status                     0
# Date_of_entry              0
# Date_of_Birth              0
# Age                        0
# Religious_affiliation      0
# Education                  1
# Marital_status             0
# Tribe_mother               8
# Tribe_father               1
# Smoking_history            0
# alcohol                    0
# bp                         0
# stroke                     0
# HIV_status                 0
# FH_diabetes                0
# FH_pre_eclampsia           1
# FH_hypertension            0
# pregnancy                  0
# order_preg                 0
# No_preg                    0
# abortions_ectopic          0
# weight_less                1
# weight_more_than           3
# d_hyp                      4
# Months                    46
# preg_duration            643
# condom                    28
# partner                   14
# H_infertility              7
# Gestational_age           65
# dtype: int64

# %% [markdown]
# ## Dropping the columns and rows.

# %%
#Dropping by column
mod_data1 = data.dropna(axis=1,thresh=350)
print(mod_data1.shape)
# Out:
# (647, 30)

# %%
#Dropping by row
mod_data1 = mod_data1.dropna()
print(mod_data1.shape)
# Out:
# (503, 30)

# %% [markdown]
# ## Graphical representation of the data

# %%
msno.matrix(mod_data1)
# Out:
# <Axes: >

# %% [markdown]
# ## Comparing the missing columns

# %%
# Assuming df1 and df2 are the two dataframes
common_columns = set(data.columns).intersection(set(mod_data1.columns))
non_common_columns = set(data.columns) - common_columns

print("Common columns in df1:", common_columns)
non_common_columns = set(data.columns) - common_columns
print("Non-common columns in df2:", non_common_columns)

print("The number of columns dopped: {}".format(len(non_common_columns)))
print("The number of rows dopped: {}".format(data.shape[0]-mod_data1.shape[0]))
# Out:
# Common columns in df1: {'Months', 'Marital_status', 'H_infertility', 'order_preg', 'Age', 'abortions_ectopic', 'weight_more_than', 'Study_ID', 'Tribe_mother', 'bp', 'Date_of_entry', 'status', 'Gestational_age', 'FH_diabetes', 'Education', 'partner', 'd_hyp', 'Smoking_history', 'Religious_affiliation', 'HIV_status', 'condom', 'Date_of_Birth', 'FH_hypertension', 'Tribe_father', 'alcohol', 'pregnancy', 'FH_pre_eclampsia', 'stroke', 'No_preg', 'weight_less'}
# Non-common columns in df2: {'preg_duration'}
# The number of columns dopped: 1
# The number of rows dopped: 144

# %% [markdown]
# ## Preview of the modified data

# %%
mod_data1.head()
# Out:
#    Study_ID  status Date_of_entry Date_of_Birth   Age  Religious_affiliation  \
# 1      5002     5.0    29-05-2019    28-12-1993  25.0                    1.0
# 2      5003     5.0    16-05-2019    07-11-1985  33.0                    2.0
# 5      5006     5.0    28-03-2019    15-02-1991  28.0                    2.0
# 6      5007     5.0    27-03-2019    17-04-1994  24.0                    1.0
# 9      5010     5.0    03-04-2019    04-06-1997  22.0                    1.0
#
#    Education  Marital_status  Tribe_mother  Tribe_father  ...  No_preg  \
# 1        4.0             1.0           3.0           3.0  ...      1.0
# 2        3.0             1.0           3.0           3.0  ...      8.0
# 5        6.0             1.0           2.0           2.0  ...      2.0
# 6        6.0             1.0           2.0           3.0  ...      1.0
# 9        3.0             1.0           3.0           3.0  ...      1.0
#
#    abortions_ectopic  weight_less  weight_more_than  d_hyp  Months  condom  \
# 1                0.0          1.0               1.0    1.0    77.0     1.0
# 2                0.0          1.0               2.0    1.0    30.0     1.0
# 5                1.0          1.0               1.0    1.0    84.0     1.0
# 6                0.0          1.0               2.0    1.0    35.0     1.0
# 9                0.0          1.0               1.0    1.0    46.0     1.0
#
#    partner  H_infertility  Gestational_age
# 1      2.0            1.0             26.0
# 2      2.0            1.0             26.0
# 5      1.0            1.0             26.0
# 6      1.0            1.0             19.0
# 9      2.0            1.0             12.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Determining the number of individuals per class

# %%
mod_data1["abortions_ectopic"].value_counts()
# Out:
# 0.0    333
# 1.0    170
# Name: abortions_ectopic, dtype: int64

# %% [markdown]
# ## Dropping columns that aren't neccessary for the model.

# %%
mod_data1.drop(columns=["Study_ID","Date_of_entry","Date_of_Birth"],inplace=True)

# %%
s = setup(mod_data1,target="abortions_ectopic",session_id=123)
# Out:
# <style type="text/css">
# #T_732f2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_732f2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_732f2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_732f2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_732f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_732f2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_732f2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_732f2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_732f2_row1_col1" class="data row1 col1" >abortions_ectopic</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_732f2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_732f2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_732f2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_732f2_row3_col1" class="data row3 col1" >(503, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_732f2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_732f2_row4_col1" class="data row4 col1" >(503, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_732f2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_732f2_row5_col1" class="data row5 col1" >(352, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_732f2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_732f2_row6_col1" class="data row6 col1" >(151, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_732f2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_732f2_row7_col1" class="data row7 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_732f2_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_732f2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_732f2_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_732f2_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_732f2_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_732f2_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_732f2_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_732f2_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_732f2_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_732f2_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_732f2_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_732f2_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_732f2_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_732f2_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_732f2_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_732f2_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_732f2_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_732f2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_732f2_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_732f2_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_732f2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_732f2_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_732f2_row18_col1" class="data row18 col1" >cc4a</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_cb4fc th {
#   text-align: left;
# }
# #T_cb4fc_row0_col0, #T_cb4fc_row1_col0, #T_cb4fc_row1_col1, #T_cb4fc_row1_col2, #T_cb4fc_row1_col3, #T_cb4fc_row1_col4, #T_cb4fc_row1_col5, #T_cb4fc_row1_col6, #T_cb4fc_row1_col7, #T_cb4fc_row2_col0, #T_cb4fc_row2_col1, #T_cb4fc_row2_col2, #T_cb4fc_row2_col3, #T_cb4fc_row2_col4, #T_cb4fc_row2_col5, #T_cb4fc_row2_col6, #T_cb4fc_row2_col7, #T_cb4fc_row3_col0, #T_cb4fc_row3_col1, #T_cb4fc_row3_col2, #T_cb4fc_row3_col3, #T_cb4fc_row3_col4, #T_cb4fc_row3_col5, #T_cb4fc_row3_col6, #T_cb4fc_row3_col7, #T_cb4fc_row4_col0, #T_cb4fc_row4_col1, #T_cb4fc_row4_col2, #T_cb4fc_row4_col3, #T_cb4fc_row4_col4, #T_cb4fc_row4_col5, #T_cb4fc_row4_col6, #T_cb4fc_row4_col7, #T_cb4fc_row5_col0, #T_cb4fc_row5_col1, #T_cb4fc_row5_col2, #T_cb4fc_row5_col3, #T_cb4fc_row5_col4, #T_cb4fc_row5_col5, #T_cb4fc_row5_col6, #T_cb4fc_row5_col7, #T_cb4fc_row6_col0, #T_cb4fc_row6_col1, #T_cb4fc_row6_col2, #T_cb4fc_row6_col3, #T_cb4fc_row6_col4, #T_cb4fc_row6_col5, #T_cb4fc_row6_col6, #T_cb4fc_row6_col7, #T_cb4fc_row7_col0, #T_cb4fc_row7_col1, #T_cb4fc_row7_col2, #T_cb4fc_row7_col3, #T_cb4fc_row7_col4, #T_cb4fc_row7_col5, #T_cb4fc_row7_col6, #T_cb4fc_row7_col7, #T_cb4fc_row8_col0, #T_cb4fc_row8_col1, #T_cb4fc_row8_col2, #T_cb4fc_row8_col3, #T_cb4fc_row8_col4, #T_cb4fc_row8_col5, #T_cb4fc_row8_col6, #T_cb4fc_row8_col7, #T_cb4fc_row9_col0, #T_cb4fc_row9_col1, #T_cb4fc_row9_col2, #T_cb4fc_row9_col3, #T_cb4fc_row9_col4, #T_cb4fc_row9_col5, #T_cb4fc_row9_col6, #T_cb4fc_row9_col7, #T_cb4fc_row10_col0, #T_cb4fc_row10_col1, #T_cb4fc_row10_col2, #T_cb4fc_row10_col4, #T_cb4fc_row10_col5, #T_cb4fc_row10_col6, #T_cb4fc_row10_col7, #T_cb4fc_row11_col0, #T_cb4fc_row11_col1, #T_cb4fc_row11_col2, #T_cb4fc_row11_col3, #T_cb4fc_row11_col4, #T_cb4fc_row11_col5, #T_cb4fc_row11_col6, #T_cb4fc_row11_col7, #T_cb4fc_row12_col0, #T_cb4fc_row12_col1, #T_cb4fc_row12_col2, #T_cb4fc_row12_col3, #T_cb4fc_row12_col4, #T_cb4fc_row12_col5, #T_cb4fc_row12_col6, #T_cb4fc_row12_col7, #T_cb4fc_row13_col0, #T_cb4fc_row13_col1, #T_cb4fc_row13_col2, #T_cb4fc_row13_col3, #T_cb4fc_row13_col4, #T_cb4fc_row13_col5, #T_cb4fc_row13_col6, #T_cb4fc_row13_col7, #T_cb4fc_row14_col0, #T_cb4fc_row14_col1, #T_cb4fc_row14_col2, #T_cb4fc_row14_col3, #T_cb4fc_row14_col4, #T_cb4fc_row14_col5, #T_cb4fc_row14_col6, #T_cb4fc_row14_col7 {
#   text-align: left;
# }
# #T_cb4fc_row0_col1, #T_cb4fc_row0_col2, #T_cb4fc_row0_col3, #T_cb4fc_row0_col4, #T_cb4fc_row0_col5, #T_cb4fc_row0_col6, #T_cb4fc_row0_col7, #T_cb4fc_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cb4fc_row0_col8, #T_cb4fc_row1_col8, #T_cb4fc_row2_col8, #T_cb4fc_row3_col8, #T_cb4fc_row4_col8, #T_cb4fc_row5_col8, #T_cb4fc_row6_col8, #T_cb4fc_row7_col8, #T_cb4fc_row8_col8, #T_cb4fc_row9_col8, #T_cb4fc_row10_col8, #T_cb4fc_row11_col8, #T_cb4fc_row13_col8, #T_cb4fc_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cb4fc_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cb4fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb4fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cb4fc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cb4fc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cb4fc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cb4fc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cb4fc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cb4fc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cb4fc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cb4fc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb4fc_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_cb4fc_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_cb4fc_row0_col1" class="data row0 col1" >0.9915</td>
#       <td id="T_cb4fc_row0_col2" class="data row0 col2" >0.9978</td>
#       <td id="T_cb4fc_row0_col3" class="data row0 col3" >0.9833</td>
#       <td id="T_cb4fc_row0_col4" class="data row0 col4" >0.9923</td>
#       <td id="T_cb4fc_row0_col5" class="data row0 col5" >0.9873</td>
#       <td id="T_cb4fc_row0_col6" class="data row0 col6" >0.9809</td>
#       <td id="T_cb4fc_row0_col7" class="data row0 col7" >0.9815</td>
#       <td id="T_cb4fc_row0_col8" class="data row0 col8" >0.5420</td>
#     </tr>
#     <tr>
#       <th id="T_cb4fc_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_cb4fc_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cb4fc_row1_col1" class="data row1 col1" >0.9687</td>
#       <td id="T_cb4fc_row1_col2" class="data row1 col2" >0.9902</td>
#       <td id="T_cb4fc_row1_col3" class="data row1 col3" >0.9492</td>
#       <td id="T_cb4fc_row1_col4" class="data row1 col4" >0.9646</td>
#       <td id="T_cb4fc_row1_col5" class="data row1 col5" >0.9544</td>
#       <td id="T_cb4fc_row1_col6" class="data row1 col6" >0.9307</td>
#       <td id="T_cb4fc_row1_col7" class="data row1 col7" >0.9336</td>
#       <td id="T_cb4fc_row1_col8" class="data row1 col8" >0.2210</td>
#     </tr>
#     <tr>
#       <th id="T_cb4fc_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_cb4fc_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cb4fc_row2_col1" class="data row2 col1" >0.9659</td>
#       <td id="T_cb4fc_row2_col2" class="data row2 col2" >0.9960</td>
#       <td id="T_cb4fc_row2_col3" class="data row2 col3" >0.9500</td>
#       <td id="T_cb4fc_row2_col4" class="data row2 col4" >0.9556</td>
#       <td id="T_cb4fc_row2_col5" class="data row2 col5" >0.9508</td>
#       <td id="T_cb4fc_row2_col6" class="data row2 col6" >0.9248</td>
#       <td id="T_cb4fc_row2_col7" class="data row2 col7" >0.9271</td>
#       <td id="T_cb4fc_row2_col8" class="data row2 col8" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_cb4fc_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_cb4fc_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cb4fc_row3_col1" class="data row3 col1" >0.9631</td>
#       <td id="T_cb4fc_row3_col2" class="data row3 col2" >0.9942</td>
#       <td id="T_cb4fc_row3_col3" class="data row3 col3" >0.9235</td>
#       <td id="T_cb4fc_row3_col4" class="data row3 col4" >0.9690</td>
#       <td id="T_cb4fc_row3_col5" class="data row3 col5" >0.9439</td>
#       <td id="T_cb4fc_row3_col6" class="data row3 col6" >0.9164</td>
#       <td id="T_cb4fc_row3_col7" class="data row3 col7" >0.9189</td>
#       <td id="T_cb4fc_row3_col8" class="data row3 col8" >0.2180</td>
#     </tr>
#     <tr>
#       <th id="T_cb4fc_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_cb4fc_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_cb4fc_row4_col1" class="data row4 col1" >0.9544</td>
#       <td id="T_cb4fc_row4_col2" class="data row4 col2" >0.9589</td>
#       <td id="T_cb4fc_row4_col3" class="data row4 col3" >0.9083</td>
#       <td id="T_cb4fc_row4_col4" class="data row4 col4" >0.9606</td>
#       <td id="T_cb4fc_row4_col5" class="data row4 col5" >0.9310</td>
#       <td id="T_cb4fc_row4_col6" class="data row4 col6" >0.8971</td>
#       <td id="T_cb4fc_row4_col7" class="data row4 col7" >0.9008</td>
#       <td id="T_cb4fc_row4_col8" class="data row4 col8" >0.3240</td>
#     </tr>
#     <tr>
#       <th id="T_cb4fc_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_cb4fc_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_cb4fc_row5_col1" class="data row5 col1" >0.9517</td>
#       <td id="T_cb4fc_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_cb4fc_row5_col3" class="data row5 col3" >0.8659</td>
#       <td id="T_cb4fc_row5_col4" class="data row5 col4" >0.9917</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
